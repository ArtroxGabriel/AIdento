# %% [markdown]
# # Preparação

# %% [markdown]
# ## Libs

# %%
from graph import Graph
from gen_alg import GeneticAlgorithm
from ant_colony import AntColony
import matplotlib.pyplot as plt

# %% [markdown]
# ## Grafo

# %%
cities = Graph([
    [0, 10, 15, 45, 5, 45, 50, 44, 30, 100, 67, 33, 90, 17, 50],
    [15, 0, 100, 30, 20, 25, 80, 45, 41, 5, 45, 10, 90, 10, 35],
    [40, 80, 0, 90, 70, 33, 100, 70, 30, 23, 80, 60, 47, 33, 25],
    [100, 8, 5, 0, 5, 40, 21, 20, 35, 14, 55, 35, 21, 5, 40],
    [17, 10, 33, 45, 0, 14, 50, 27, 33, 60, 17, 10, 20, 13, 71],
    [15, 70, 90, 20, 11, 0, 15, 35, 30, 15, 18, 35, 15, 90, 23],
    [25, 19, 18, 30, 100, 55, 0, 70, 55, 41, 55, 100, 18, 14, 18],
    [40, 15, 60, 45, 70, 33, 25, 0, 27, 60, 80, 35, 30, 41, 35],
    [21, 34, 17, 10, 11, 40, 8, 32, 0, 47, 76, 40, 21, 90, 21],
    [35, 100, 5, 18, 43, 25, 14, 30, 39, 0, 17, 35, 15, 13, 40],
    [38, 20, 23, 30, 5, 55, 50, 33, 70, 14, 0, 60, 30, 35, 21],
    [15, 14, 45, 21, 100, 10, 8, 20, 35, 43, 8, 0, 15, 100, 23],
    [80, 10, 5, 20, 35, 8, 90, 5, 44, 10, 80, 14, 0, 25, 80],
    [33, 90, 40, 18, 70, 45, 25, 23, 90, 44, 43, 70, 5, 0, 25],
    [25, 70, 45, 50, 5, 45, 20, 100, 25, 50, 35, 10, 90, 5, 0],
])

# %% [markdown]
# # Algoritmo Genético

# %%
gen = GeneticAlgorithm(graph=cities, pop_size=1000)
gen_best_path = gen.fit(max_epochs=100)
gen_best_distance = cities.get_path_cost(gen_best_path)

# %%
print('Algoritmo Genético:')
print(f'Melhor caminho: {gen_best_path}')
print(f'Menor custo: {gen_best_distance}')
# Out:
# Algoritmo Genético:
# Melhor caminho: [8, 3, 13, 12, 7, 1, 9, 10, 4, 5, 6, 14, 11, 0, 2, 8]
# Menor custo: 184

# %%
plt.plot(range(100), gen.loss)
plt.title('Função de custo do Alg. Genético')
# Out:
# Text(0.5, 1.0, 'Função de custo do Alg. Genético')

# %% [markdown]
# # Colônia de Formigas

# %%
ac = AntColony(graph=cities, 
                alpha = 1,
                beta = 1,
                ro = 0.95,
                Q = 1,
                num_ants=100)

ac_best_path = ac.fit(max_epochs=100)
ac_best_distance = cities.get_path_cost(ac_best_path)

# %%
print('Algoritmo Genético:')
print(f'Melhor caminho: {ac_best_path}')
print(f'Menor custo: {ac_best_distance}')
# Out:
# Algoritmo Genético:
# Melhor caminho: [4, 5, 0, 13, 12, 7, 1, 9, 2, 8, 3, 6, 14, 11, 10, 4]
# Menor custo: 183

# %%
plt.plot(range(100), ac.loss)
plt.title('Função de custo da Colônia de Formigas')
# Out:
# Text(0.5, 1.0, 'Função de custo da Colônia de Formigas')
